# %% [markdown]
# # Stack overflow 2019 developer survey
# ## Analysing Developer type, Education level and Most Common Language used by developers

# %%
import pandas as pd

# %%
survey_data = pd.read_csv('survey_results2019.csv')

# %%
survey_data.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
# 5                       Never
# 6                       Never
# 7     Less than once per year
# 8  Once a month or more often
# 9  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
# 5  The quality of OSS and closed source software ...
# 6  The quality of OSS and closed source software ...
# 7  OSS is, on average, of HIGHER quality than pro...
# 8  The quality of OSS and closed source software ...
# 9  OSS is, on average, of HIGHER quality than pro...
#
#                                           Employment                 Country  \
# 0             Not employed, and not looking for work          United Kingdom
# 1                 Not employed, but looking for work  Bosnia and Herzegovina
# 2                                 Employed full-time                Thailand
# 3                                 Employed full-time           United States
# 4                                 Employed full-time                 Ukraine
# 5                                 Employed full-time                  Canada
# 6  Independent contractor, freelancer, or self-em...                 Ukraine
# 7                 Not employed, but looking for work                   India
# 8                                 Employed full-time             New Zealand
# 9                                 Employed full-time                   India
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
# 2              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7             NaN           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8              No  Some college/university study without earning ...
# 9              No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                       UndergradMajor  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                      Web development or web design  ...
# 3  Computer science, computer engineering, or sof...  ...
# 4  Computer science, computer engineering, or sof...  ...
# 5                          Mathematics or statistics  ...
# 6  Another engineering discipline (ex. civil, ele...  ...
# 7  Computer science, computer engineering, or sof...  ...
# 8  Computer science, computer engineering, or sof...  ...
# 9                                                NaN  ...
#
#                               WelcomeChange  \
# 0   Just as welcome now as I felt last year
# 1   Just as welcome now as I felt last year
# 2   Just as welcome now as I felt last year
# 3   Just as welcome now as I felt last year
# 4   Just as welcome now as I felt last year
# 5   Just as welcome now as I felt last year
# 6     A lot more welcome now than last year
# 7     A lot more welcome now than last year
# 8   Just as welcome now as I felt last year
# 9  Somewhat less welcome now than last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
# 1  Tech articles written by other developers;Indu...  19.0    Man    No
# 2  Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3  Tech articles written by other developers;Indu...  22.0    Man    No
# 4  Tech meetups or events in your area;Courses on...  30.0    Man    No
# 5  Tech articles written by other developers;Indu...  28.0    Man    No
# 6                                                NaN  42.0    Man    No
# 7  Tech articles written by other developers;Indu...  24.0    Man    No
# 8                                                NaN  23.0    Man    No
# 9  Tech articles written by other developers;Tech...   NaN    NaN   NaN
#
#                  Sexuality                                 Ethnicity  \
# 0  Straight / Heterosexual                                       NaN
# 1  Straight / Heterosexual                                       NaN
# 2  Straight / Heterosexual                                       NaN
# 3  Straight / Heterosexual              White or of European descent
# 4  Straight / Heterosexual  White or of European descent;Multiracial
# 5  Straight / Heterosexual                                East Asian
# 6  Straight / Heterosexual              White or of European descent
# 7  Straight / Heterosexual                                       NaN
# 8                 Bisexual              White or of European descent
# 9                      NaN                                       NaN
#
#   Dependents           SurveyLength                  SurveyEase
# 0         No  Appropriate in length  Neither easy nor difficult
# 1         No  Appropriate in length  Neither easy nor difficult
# 2        Yes  Appropriate in length  Neither easy nor difficult
# 3         No  Appropriate in length                        Easy
# 4         No  Appropriate in length                        Easy
# 5         No               Too long  Neither easy nor difficult
# 6        Yes  Appropriate in length  Neither easy nor difficult
# 7        NaN  Appropriate in length  Neither easy nor difficult
# 8         No  Appropriate in length  Neither easy nor difficult
# 9        Yes               Too long                   Difficult
#
# [10 rows x 85 columns]

# %%
summ = pd.DataFrame({'count': 
    summ.sum(axis=1)
    .groupby(lambda x: x.strip())
    .sum()})
summ
# Out:
#                                                            count
# Associate degree                                     2941.400857
# Bachelor’s degree (BA, BS, B.Eng., etc.)            39179.299224
# I never completed any formal education                553.640120
# Master’s degree (MA, MS, M.Eng., MBA, etc.)         19591.651927
# Other doctoral degree (Ph.D, Ed.D., etc.)            2434.815141
# Primary/elementary school                            1423.646024
# Professional degree (JD, MD, etc.)                   1199.386735
# Secondary school (e.g. American high school, Ge...   8652.003473
# Some college/university study without earning a...  10514.156500

# %%
tot = survey_data[survey_data['EdLevel'].notnull()].shape[0]
summ['percent'] = summ['count']/tot*100
summ
# Out:
#                                                            count    percent
# Associate degree                                     2941.400857   3.404793
# Bachelor’s degree (BA, BS, B.Eng., etc.)            39179.299224  45.351660
# I never completed any formal education                553.640120   0.640861
# Master’s degree (MA, MS, M.Eng., MBA, etc.)         19591.651927  22.678148
# Other doctoral degree (Ph.D, Ed.D., etc.)            2434.815141   2.818399
# Primary/elementary school                            1423.646024   1.647929
# Professional degree (JD, MD, etc.)                   1199.386735   1.388340
# Secondary school (e.g. American high school, Ge...   8652.003473  10.015052
# Some college/university study without earning a...  10514.156500  12.170571

# %%
summ.plot.barh(y='percent', figsize=(5,5))

# %%
dev_sum = pd.DataFrame({'count': 
    dev_sum.sum(axis=1)
    .groupby(lambda x: x.strip())
    .sum()})
dev_sum
# Out:
#                                                       count
# Academic researcher                             5957.504592
# Data or business analyst                        6323.192901
# Data scientist or machine learning specialist   6489.962844
# Database administrator                          9564.155770
# Designer                                        9224.588055
# DevOps specialist                               8903.103827
# Developer, QA or test                           6388.494385
# Developer, back-end                            40853.612856
# Developer, desktop or enterprise applications  17396.315264
# Developer, embedded applications or devices     7281.617754
# Developer, front-end                           26772.603689
# Developer, full-stack                          42417.834551
# Developer, game or graphics                     4459.589019
# Developer, mobile                              14766.172427
# Educator                                        4512.834844
# Engineer, data                                  5845.989751
# Engineer, site reliability                      2964.687361
# Engineering manager                             4221.489763
# Marketing or sales professional                  979.522256
# Product manager                                 4050.701267
# Scientist                                       3633.776410
# Senior executive/VP                             2116.772711
# Student                                        11976.292115
# System administrator                            8970.414587

# %%
total_dev = survey_data[survey_data['DevType'].notnull()].shape[0]
dev_sum['percent'] = dev_sum['count']/tot*100
dev_sum
# Out:
#                                                       count    percent
# Academic researcher                             5957.504592   6.896058
# Data or business analyst                        6323.192901   7.319357
# Data scientist or machine learning specialist   6489.962844   7.512401
# Database administrator                          9564.155770  11.070906
# Designer                                        9224.588055  10.677842
# DevOps specialist                               8903.103827  10.305711
# Developer, QA or test                           6388.494385   7.394947
# Developer, back-end                            40853.612856  47.289747
# Developer, desktop or enterprise applications  17396.315264  20.136955
# Developer, embedded applications or devices     7281.617754   8.428774
# Developer, front-end                           26772.603689  30.990397
# Developer, full-stack                          42417.834551  49.100399
# Developer, game or graphics                     4459.589019   5.162159
# Developer, mobile                              14766.172427  17.092456
# Educator                                        4512.834844   5.223793
# Engineer, data                                  5845.989751   6.766975
# Engineer, site reliability                      2964.687361   3.431748
# Engineering manager                             4221.489763   4.886549
# Marketing or sales professional                  979.522256   1.133838
# Product manager                                 4050.701267   4.688854
# Scientist                                       3633.776410   4.206247
# Senior executive/VP                             2116.772711   2.450252
# Student                                        11976.292115  13.863054
# System administrator                            8970.414587  10.383626

# %%
dev_sum.plot.barh(y='percent', figsize=(15,15))

# %%
summary = pd.DataFrame({'count': 
    summary.sum(axis=1)
    .groupby(lambda x: x.strip())
    .sum()})
summary
# Out:
#                               count
# Assembly                5839.661033
# Bash/Shell/PowerShell  32027.532335
# C                      18037.574633
# C#                     27127.943599
# C++                    20547.437518
# Clojure                 1255.432014
# Dart                    1684.921913
# Elixir                  1261.438865
# Erlang                   777.887300
# F#                       974.111124
# Go                      7209.223230
# HTML/CSS               55529.339766
# Java                   35958.015656
# JavaScript             59286.625530
# Kotlin                  5626.417796
# Objective-C             4195.785940
# Other(s):               7929.044296
# PHP                    23056.299261
# Python                 36484.616325
# R                       5053.764597
# Ruby                    7339.371684
# Rust                    2797.190627
# SQL                    47598.293186
# Scala                   3312.778734
# Swift                   5750.559399
# TypeScript             18544.152463
# VBA                     4786.459695
# WebAssembly             1016.159086

# %%
total = survey_data[survey_data['LanguageWorkedWith'].notnull()].shape[0]
summary['percent'] = summary['count']/total*100
summary
# Out:
#                               count    percent
# Assembly                5839.661033   6.668640
# Bash/Shell/PowerShell  32027.532335  36.574053
# C                      18037.574633  20.598128
# C#                     27127.943599  30.978935
# C++                    20547.437518  23.464282
# Clojure                 1255.432014   1.433649
# Dart                    1684.921913   1.924108
# Elixir                  1261.438865   1.440508
# Erlang                   777.887300   0.888314
# F#                       974.111124   1.112393
# Go                      7209.223230   8.232620
# HTML/CSS               55529.339766  63.412098
# Java                   35958.015656  41.062494
# JavaScript             59286.625530  67.702755
# Kotlin                  5626.417796   6.425125
# Objective-C             4195.785940   4.791406
# Other(s):               7929.044296   9.054625
# PHP                    23056.299261  26.329294
# Python                 36484.616325  41.663849
# R                       5053.764597   5.771180
# Ruby                    7339.371684   8.381244
# Rust                    2797.190627   3.194270
# SQL                    47598.293186  54.355186
# Scala                   3312.778734   3.783050
# Swift                   5750.559399   6.566889
# TypeScript             18544.152463  21.176618
# VBA                     4786.459695   5.465929
# WebAssembly             1016.159086   1.160410

# %%
summary.plot.barh(y='percent', figsize=(15,15))
