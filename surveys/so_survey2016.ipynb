# %% [markdown]
# # Stack overflow 2016 developer survey
# ## Analysing Developer type, Education level and Most Common Language used by developers

# %%
import pandas as pd
survey_data = pd.read_csv('survey_results2016.csv')
survey_data.head(10)
# Out:
#    Unnamed: 0 collector      country     un_subregion       so_region  \
# 0        1888  Facebook  Afghanistan    Southern Asia    Central Asia
# 1        4637  Facebook  Afghanistan    Southern Asia    Central Asia
# 2       11164  Facebook  Afghanistan    Southern Asia    Central Asia
# 3       21378  Facebook  Afghanistan    Southern Asia    Central Asia
# 4       30280  Facebook  Afghanistan    Southern Asia    Central Asia
# 5       31355  Facebook  Afghanistan    Southern Asia    Central Asia
# 6       31743  Facebook  Afghanistan    Southern Asia    Central Asia
# 7       51301  Facebook  Afghanistan    Southern Asia    Central Asia
# 8       13017  Facebook      Albania  Southern Europe  Eastern Europe
# 9       24487  Facebook      Albania  Southern Europe  Eastern Europe
#
#                 age_range  age_midpoint                  gender  \
# 0                   20-24          22.0                    Male
# 1                   30-34          32.0                    Male
# ...

# %%
edu_sum = pd.DataFrame({'count': 
    edu_sum.sum(axis=1)
    .groupby(lambda x: x.strip())
    .sum()})
edu_sum
# Out:
#                                                       count
# B.A. in Computer Science (or related field)          3858.0
# B.S. in Computer Science (or related field)         15494.0
# Full-time, intensive program (e.g. "boot-camp")      2819.0
# I'm self-taught                                     31508.0
# Industry certification program                       3002.0
# Masters Degree in Computer Science (or related ...   8441.0
# Mentorship program (e.g. Flatiron School, GDI, ...    560.0
# On-the-job training                                 18548.0
# Online class (e.g. Coursera, Codecademy, Khan A...  11861.0
# Part-time program (e.g. night school)                1812.0
# PhD in Computer Science (or related field)            919.0
# Some college coursework in Computer Science (or...   9384.0

# %%
total_edu = survey_data[survey_data['education'].notnull()].shape[0]
edu_sum['percent'] = edu_sum['count']/total_edu*100
edu_sum
# Out:
#                                                       count    percent
# B.A. in Computer Science (or related field)          3858.0   8.581915
# B.S. in Computer Science (or related field)         15494.0  34.465577
# Full-time, intensive program (e.g. "boot-camp")      2819.0   6.270715
# I'm self-taught                                     31508.0  70.087866
# Industry certification program                       3002.0   6.677789
# Masters Degree in Computer Science (or related ...   8441.0  18.776554
# Mentorship program (e.g. Flatiron School, GDI, ...    560.0   1.245690
# On-the-job training                                 18548.0  41.259037
# Online class (e.g. Coursera, Codecademy, Khan A...  11861.0  26.384162
# Part-time program (e.g. night school)                1812.0   4.030697
# PhD in Computer Science (or related field)            919.0   2.044266
# Some college coursework in Computer Science (or...   9384.0  20.874208

# %%
edu_sum.plot.barh(y='percent', figsize=(5,5))

# %%
dev_sum = pd.DataFrame({'count': 
    dev_sum.sum(axis=1)
    .groupby(lambda x: x.strip())
    .sum()})
dev_sum
# Out:
#                                                     count
# Analyst                                               570
# Back-end web developer                               6061
# Business intelligence or data warehousing expert      392
# Data scientist                                        800
# Database administrator                                258
# Designer                                              333
# Desktop developer                                    3390
# DevOps                                               1074
# Developer with a statistics or mathematics back...    960
# Embedded application developer                       1268
# Engineering manager                                   697
# Enterprise level services developer                  1471
# Executive (VP of Eng., CTO, CIO, etc.)                888
# Front-end web developer                              2873
# Full-stack web developer                            13886
# ...

# %%
total_dev = survey_data[survey_data['occupation'].notnull()].shape[0]
dev_sum['percent'] = dev_sum['count']/total_dev*100
dev_sum
# Out:
#                                                     count    percent
# Analyst                                               570   1.151073
# Back-end web developer                               6061  12.239746
# Business intelligence or data warehousing expert      392   0.791615
# Data scientist                                        800   1.615542
# Database administrator                                258   0.521012
# Designer                                              333   0.672469
# Desktop developer                                    3390   6.845857
# DevOps                                               1074   2.168864
# Developer with a statistics or mathematics back...    960   1.938650
# Embedded application developer                       1268   2.560633
# Engineering manager                                   697   1.407541
# Enterprise level services developer                  1471   2.970577
# Executive (VP of Eng., CTO, CIO, etc.)                888   1.793251
# ...

# %%
dev_sum.plot.barh(y='percent', figsize=(10,10))

# %%
summary = pd.DataFrame({'count': 
    summary.sum(axis=1)
    .groupby(lambda x: x.strip())
    .sum()})
summary
# Out:
#                                  count
# Android                         8601.0
# AngularJS                       8823.0
# Arduino / Raspberry Pi          3797.0
# C                               7678.0
# C#                             15283.0
# C++                             9589.0
# Cassandra                        663.0
# Clojure                          556.0
# Cloud (AWS, GAE, Azure, etc.)   4629.0
# CoffeeScript                    1662.0
# Cordova                         1651.0
# Dart                             222.0
# F#                               484.0
# Go                              1547.0
# Hadoop                          1012.0
# Haskell                          813.0
# Java                           17942.0
# JavaScript                     27385.0
# LAMP                            4821.0
# Matlab                          1602.0
# MongoDB                         4780.0
# Node.js                         8509.0
# Objective-C                     3202.0
# ...

# %%
total = survey_data[survey_data['tech_do'].notnull()].shape[0]
summary['percent'] = summary['count']/total*100
summary
# Out:
#                                  count    percent
# Android                         8601.0  17.544110
# AngularJS                       8823.0  17.996940
# Arduino / Raspberry Pi          3797.0   7.745028
# C                               7678.0  15.661397
# C#                             15283.0  31.173891
# C++                             9589.0  19.559408
# Cassandra                        663.0   1.352371
# Clojure                          556.0   1.134115
# Cloud (AWS, GAE, Azure, etc.)   4629.0   9.442121
# CoffeeScript                    1662.0   3.390107
# Cordova                         1651.0   3.367670
# Dart                             222.0   0.452830
# F#                               484.0   0.987251
# Go                              1547.0   3.155533
# Hadoop                          1012.0   2.064253
# Haskell                          813.0   1.658338
# Java                           17942.0  36.597654
# JavaScript                     27385.0  55.859255
# ...

# %%
summary.plot.barh(y='percent', figsize=(15,15))
