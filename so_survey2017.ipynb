# %% [markdown]
# # Stack overflow 2017 developer survey
# ## Analysing Education level, Developer type and Most Common Language used by developers

# %%
import pandas as pd
survey_data = pd.read_csv('survey_results2017.csv')
survey_data.head(10)
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
# 5           6                                            Student
# 6           7  Professional non-developer who sometimes write...
# 7           8                             Professional developer
# 8           9                             Professional developer
# 9          10                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# ...

# %%
edu_sum = pd.DataFrame({'count': 
    edu_sum.sum(axis=1)
    .groupby(lambda x: x.strip())
    .sum()})
edu_sum
# Out:
#                                                     count
# Bachelor's degree                                   21609
# Doctoral degree                                      1308
# I never completed any formal education                426
# I prefer not to answer                               1109
# Master's degree                                     11141
# Primary/elementary school                            1047
# Professional degree                                   715
# Secondary school                                     5908
# Some college/university study without earning a...   8129

# %%
total_edu = survey_data[survey_data['FormalEducation'].notnull()].shape[0]
edu_sum['percent'] = edu_sum['count']/total_edu*100
edu_sum
# Out:
#                                                     count    percent
# Bachelor's degree                                   21609  42.047400
# Doctoral degree                                      1308   2.545143
# I never completed any formal education                426   0.828923
# I prefer not to answer                               1109   2.157923
# Master's degree                                     11141  21.678471
# Primary/elementary school                            1047   2.037282
# Professional degree                                   715   1.391267
# Secondary school                                     5908  11.495953
# Some college/university study without earning a...   8129  15.817637

# %%
edu_sum.plot.barh(y='percent', figsize=(15,15))

# %%
dev_sum = pd.DataFrame({'count': 
    dev_sum.sum(axis=1)
    .groupby(lambda x: x.strip())
    .sum()})
dev_sum
# Out:
#                                                       count
# Data scientist                                       3045.0
# Database administrator                               5192.0
# Desktop applications developer                      10435.0
# DevOps specialist                                    4015.0
# Developer with a statistics or mathematics back...   4091.0
# Embedded applications/devices developer              3352.0
# Graphic designer                                     1426.0
# Graphics programming                                 1731.0
# Machine learning specialist                          1379.0
# Mobile developer                                     8326.0
# Other                                                2694.0
# Quality assurance engineer                           1252.0
# Systems administrator                                4086.0
# Web developer                                       26235.0

# %%
total_dev = survey_data[survey_data['DeveloperType'].notnull()].shape[0]
dev_sum['percent'] = dev_sum['count']/total_dev*100
dev_sum
# Out:
#                                                       count    percent
# Data scientist                                       3045.0   8.429066
# Database administrator                               5192.0  14.372318
# Desktop applications developer                      10435.0  28.885813
# DevOps specialist                                    4015.0  11.114187
# Developer with a statistics or mathematics back...   4091.0  11.324567
# Embedded applications/devices developer              3352.0   9.278893
# Graphic designer                                     1426.0   3.947405
# Graphics programming                                 1731.0   4.791696
# Machine learning specialist                          1379.0   3.817301
# Mobile developer                                     8326.0  23.047751
# Other                                                2694.0   7.457439
# Quality assurance engineer                           1252.0   3.465744
# ...

# %%
dev_sum.plot.barh(y='percent', figsize=(15,15))

# %%
summary = pd.DataFrame({'count': 
    summary.sum(axis=1)
    .groupby(lambda x: x.strip())
    .sum()})
summary
# Out:
#                   count
# Assembly         1823.0
# C                6974.0
# C#              12476.0
# C++              8155.0
# Clojure           391.0
# CoffeeScript     1192.0
# Common Lisp       273.0
# Dart              145.0
# Elixir            380.0
# Erlang            281.0
# F#                457.0
# Go               1557.0
# Groovy           1193.0
# Hack              107.0
# Haskell           649.0
# Java            14524.0
# JavaScript      22875.0
# Julia             138.0
# Lua              1039.0
# Matlab           1569.0
# Objective-C      2349.0
# PHP             10290.0
# Perl             1585.0
# Python          11704.0
# R                1634.0
# Ruby             3324.0
# Rust              416.0
# SQL             18754.0
# Scala            1309.0
# Smalltalk         327.0
# Swift            2368.0
# TypeScript       3488.0
# VB.NET           2273.0
# VBA              1574.0
# Visual Basic 6   1071.0

# %%
total = survey_data[survey_data['HaveWorkedLanguage'].notnull()].shape[0]
summary['percent'] = summary['count']/total*100
summary
# Out:
#                   count    percent
# Assembly         1823.0   4.977474
# C                6974.0  19.041638
# C#              12476.0  34.064164
# C++              8155.0  22.266212
# Clojure           391.0   1.067577
# CoffeeScript     1192.0   3.254608
# Common Lisp       273.0   0.745392
# Dart              145.0   0.395904
# Elixir            380.0   1.037543
# Erlang            281.0   0.767235
# F#                457.0   1.247782
# Go               1557.0   4.251195
# Groovy           1193.0   3.257338
# Hack              107.0   0.292150
# Haskell           649.0   1.772014
# Java            14524.0  39.655973
# JavaScript      22875.0  62.457338
# Julia             138.0   0.376792
# Lua              1039.0   2.836860
# Matlab           1569.0   4.283959
# Objective-C      2349.0   6.413652
# PHP             10290.0  28.095563
# Perl             1585.0   4.327645
# Python          11704.0  31.956314
# R                1634.0   4.461433
# Ruby             3324.0   9.075768
# ...

# %%
summary.plot.barh(y='percent', figsize=(15,15))
