# %% [markdown]
# # Stack overflow 2018 developer survey
# ## Analysing Education level, Developer type and Most Common Language used by developers

# %%
import pandas as pd
survey_data = pd.read_csv('survey_results2018.csv')
survey_data.head(10)
# Out:
#    Respondent Hobby OpenSource         Country         Student  \
# 0           1   Yes         No           Kenya              No
# 1           3   Yes        Yes  United Kingdom              No
# 2           4   Yes        Yes   United States              No
# 3           5    No         No   United States              No
# 4           7   Yes         No    South Africa  Yes, part-time
# 5           8   Yes         No  United Kingdom              No
# 6           9   Yes        Yes   United States              No
# 7          10   Yes        Yes         Nigeria              No
# 8          11   Yes        Yes   United States              No
# 9          16    No        Yes           India              No
#
#            Employment                                    FormalEducation  \
# 0  Employed part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  Employed full-time                                   Associate degree
# 3  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4  Employed full-time  Some college/university study without earning ...
# 5  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6  Employed full-time  Some college/university study without earning ...
# 7  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8  Employed full-time  Some college/university study without earning ...
# 9  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# 1  A natural science (ex. biology, chemistry, phy...
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
# 5  Computer science, computer engineering, or sof...
# 6  Computer science, computer engineering, or sof...
# 7  Computer science, computer engineering, or sof...
# 8  Fine arts or performing arts (ex. graphic desi...
# 9  Computer science, computer engineering, or sof...
#
#                 CompanySize  \
# 0        20 to 99 employees
# 1  10,000 or more employees
# 2        20 to 99 employees
# 3      100 to 499 employees
# 4  10,000 or more employees
# 5        10 to 19 employees
# 6  10,000 or more employees
# 7        10 to 19 employees
# 8      100 to 499 employees
# 9      500 to 999 employees
#
#                                              DevType  ...  \
# 0                               Full-stack developer  ...
# 1  Database administrator;DevOps specialist;Full-...  ...
# 2           Engineering manager;Full-stack developer  ...
# 3                               Full-stack developer  ...
# 4  Data or business analyst;Desktop or enterprise...  ...
# 5  Back-end developer;Database administrator;Fron...  ...
# 6  Back-end developer;Front-end developer;Full-st...  ...
# 7  Designer;Front-end developer;QA or test developer  ...
# 8  Back-end developer;C-suite executive (CEO, CTO...  ...
# 9                                           Designer  ...
#
#                      Exercise  Gender         SexualOrientation  \
# 0        3 - 4 times per week    Male  Straight or heterosexual
# 1   Daily or almost every day    Male  Straight or heterosexual
# 2                         NaN     NaN                       NaN
# 3  I don't typically exercise    Male  Straight or heterosexual
# 4        3 - 4 times per week    Male  Straight or heterosexual
# 5        1 - 2 times per week    Male  Straight or heterosexual
# 6  I don't typically exercise    Male  Straight or heterosexual
# 7        1 - 2 times per week  Female                       NaN
# 8  I don't typically exercise    Male  Straight or heterosexual
# 9                         NaN     NaN                       NaN
#
#                                     EducationParents  \
# 0           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2                                                NaN
# 3  Some college/university study without earning ...
# 4  Some college/university study without earning ...
# 5  Secondary school (e.g. American high school, G...
# 6        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 7                          Primary/elementary school
# 8  Some college/university study without earning ...
# 9                                                NaN
#
#                   RaceEthnicity                Age Dependents  MilitaryUS  \
# 0   Black or of African descent  25 - 34 years old        Yes         NaN
# 1  White or of European descent  35 - 44 years old        Yes         NaN
# 2                           NaN                NaN        NaN         NaN
# 3  White or of European descent  35 - 44 years old         No          No
# 4  White or of European descent  18 - 24 years old        Yes         NaN
# 5  White or of European descent  18 - 24 years old         No         NaN
# 6  White or of European descent  18 - 24 years old         No          No
# 7   Black or of African descent  25 - 34 years old         No         NaN
# 8  White or of European descent  35 - 44 years old        Yes          No
# 9                           NaN                NaN        NaN         NaN
#
#                           SurveyTooLong          SurveyEasy
# 0  The survey was an appropriate length           Very easy
# 1  The survey was an appropriate length       Somewhat easy
# 2                                   NaN                 NaN
# 3  The survey was an appropriate length       Somewhat easy
# 4  The survey was an appropriate length       Somewhat easy
# 5  The survey was an appropriate length       Somewhat easy
# 6  The survey was an appropriate length       Somewhat easy
# 7               The survey was too long  Somewhat difficult
# 8  The survey was an appropriate length           Very easy
# 9                                   NaN                 NaN
#
# [10 rows x 129 columns]

# %%
edu_sum = pd.DataFrame({'count': 
    edu_sum.sum(axis=1)
    .groupby(lambda x: x.strip())
    .sum()})
edu_sum
# Out:
#                                                            count
# Associate degree                                     2973.136120
# Bachelor’s degree (BA, BS, B.Eng., etc.)            43705.100968
# I never completed any formal education                700.739153
# Master’s degree (MA, MS, M.Eng., MBA, etc.)         21418.592737
# Other doctoral degree (Ph.D, Ed.D., etc.)            2216.337835
# Primary/elementary school                            1657.748625
# Professional degree (JD, MD, etc.)                   1448.527935
# Secondary school (e.g. American high school, Ge...   8960.451654
# Some college/university study without earning a...  11722.364973

# %%
total_edu = survey_data[survey_data['FormalEducation'].notnull()].shape[0]
edu_sum['percent'] = edu_sum['count']/total_edu*100
edu_sum
# Out:
#                                                            count    percent
# Associate degree                                     2973.136120   3.139432
# Bachelor’s degree (BA, BS, B.Eng., etc.)            43705.100968  46.149648
# I never completed any formal education                700.739153   0.739933
# Master’s degree (MA, MS, M.Eng., MBA, etc.)         21418.592737  22.616594
# Other doctoral degree (Ph.D, Ed.D., etc.)            2216.337835   2.340304
# Primary/elementary school                            1657.748625   1.750471
# Professional degree (JD, MD, etc.)                   1448.527935   1.529548
# Secondary school (e.g. American high school, Ge...   8960.451654   9.461634
# Some college/university study without earning a...  11722.364973  12.378029

# %%
edu_sum.plot.barh(y='percent', figsize=(15,15))

# %%
dev_sum = pd.DataFrame({'count': 
    dev_sum.sum(axis=1)
    .groupby(lambda x: x.strip())
    .sum()})
dev_sum
# Out:
#                                                  count
# Back-end developer                             53300.0
# C-suite executive (CEO, CTO, etc.)              3491.0
# Data or business analyst                        7559.0
# Data scientist or machine learning specialist   7088.0
# Database administrator                         13216.0
# Designer                                       12019.0
# Desktop or enterprise applications developer   15807.0
# DevOps specialist                               9549.0
# Educator or academic researcher                 3641.0
# Embedded applications or devices developer      4819.0
# Engineering manager                             5256.0
# Front-end developer                            34822.0
# Full-stack developer                           44353.0
# Game or graphics developer                      4642.0
# Marketing or sales professional                 1122.0
# Mobile developer                               18804.0
# Product manager                                 4316.0
# QA or test developer                            6194.0
# Student                                        15732.0
# System administrator                           10375.0

# %%
total_dev = survey_data[survey_data['DevType'].notnull()].shape[0]
dev_sum['percent'] = dev_sum['count']/total_dev*100
dev_sum
# Out:
#                                                  count    percent
# Back-end developer                             53300.0  57.873135
# C-suite executive (CEO, CTO, etc.)              3491.0   3.790527
# Data or business analyst                        7559.0   8.207562
# Data scientist or machine learning specialist   7088.0   7.696150
# Database administrator                         13216.0  14.349932
# Designer                                       12019.0  13.050229
# Desktop or enterprise applications developer   15807.0  17.163239
# DevOps specialist                               9549.0  10.368303
# Educator or academic researcher                 3641.0   3.953397
# Embedded applications or devices developer      4819.0   5.232470
# Engineering manager                             5256.0   5.706964
# Front-end developer                            34822.0  37.809724
# Full-stack developer                           44353.0  48.158483
# Game or graphics developer                      4642.0   5.040283
# Marketing or sales professional                 1122.0   1.218267
# Mobile developer                               18804.0  20.417381
# Product manager                                 4316.0   4.686312
# QA or test developer                            6194.0   6.725445
# Student                                        15732.0  17.081804
# System administrator                           10375.0  11.265174

# %%
dev_sum.plot.barh(y='percent', figsize=(15,15))

# %%
summary = pd.DataFrame({'count': 
    summary.sum(axis=1)
    .groupby(lambda x: x.strip())
    .sum()})
summary
# Out:
#                         count
# Assembly               5760.0
# Bash/Shell            31172.0
# C                     18042.0
# C#                    26954.0
# C++                   19872.0
# CSS                   50979.0
# Clojure                1032.0
# Cobol                   590.0
# CoffeeScript           2603.0
# Delphi/Object Pascal   2025.0
# Erlang                  886.0
# F#                     1115.0
# Go                     5532.0
# Groovy                 3373.0
# HTML                  53628.0
# Hack                    254.0
# Haskell                1961.0
# Java                  35521.0
# JavaScript            54686.0
# Julia                   430.0
# Kotlin                 3508.0
# Lua                    2733.0
# Matlab                 4564.0
# Objective-C            5510.0
# Ocaml                   470.0
# PHP                   24071.0
# Perl                   3280.0
# Python                30359.0
# R                      4813.0
# Ruby                   7911.0
# Rust                   1857.0
# SQL                   44670.0
# Scala                  3420.0
# Swift                  6310.0
# TypeScript            13626.0
# VB.NET                 5254.0
# VBA                    3810.0
# Visual Basic 6         3087.0

# %%
total = survey_data[survey_data['LanguageWorkedWith'].notnull()].shape[0]
summary['percent'] = summary['count']/total*100
summary
# Out:
#                         count    percent
# Assembly               5760.0   7.353129
# Bash/Shell            31172.0  39.793704
# C                     18042.0  23.032144
# C#                    26954.0  34.409069
# C++                   19872.0  25.368295
# CSS                   50979.0  65.079021
# Clojure                1032.0   1.317436
# Cobol                   590.0   0.753185
# CoffeeScript           2603.0   3.322950
# Delphi/Object Pascal   2025.0   2.585084
# Erlang                  886.0   1.131054
# F#                     1115.0   1.423392
# Go                     5532.0   7.062068
# Groovy                 3373.0   4.305921
# HTML                  53628.0  68.460694
# Hack                    254.0   0.324253
# Haskell                1961.0   2.503383
# Java                  35521.0  45.345572
# JavaScript            54686.0  69.811321
# Julia                   430.0   0.548931
# Kotlin                 3508.0   4.478260
# Lua                    2733.0   3.488906
# Matlab                 4564.0   5.826333
# Objective-C            5510.0   7.033983
# Ocaml                   470.0   0.599995
# PHP                   24071.0  30.728675
# Perl                   3280.0   4.187198
# Python                30359.0  38.755840
# R                      4813.0   6.144203
# Ruby                   7911.0  10.099063
# Rust                   1857.0   2.370618
# SQL                   44670.0  57.025047
# Scala                  3420.0   4.365920
# Swift                  6310.0   8.055251
# TypeScript            13626.0  17.394746
# VB.NET                 5254.0   6.707177
# VBA                    3810.0   4.863788
# Visual Basic 6         3087.0   3.940818

# %%
summary.plot.barh(y='percent', figsize=(15,15))
